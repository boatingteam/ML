# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

df = pd.read_csv('heart_disease_data.csv', header = 0)

x = np.array(df.iloc[:,0:10])
y = np.array(df['num'])

from sklearn import svm
svc = svm.SVC(kernel = 'linear')

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

accuracy, precision, recall = list(), list(), list()

for i in range(20):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)
    
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train = scaler.transform(x_train)
    x_test = scaler.transform(x_test)
    
    svc.fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    print(confusion_matrix(y_test, y_pred))

    accuracy.append(accuracy_score(y_test, y_pred))
    precision.append(precision_score(y_test, y_pred, pos_label = 1))
    recall.append(recall_score(y_test, y_pred, pos_label = 1))
    print(classification_report(y_test, y_pred))

print('accuracy = ', accuracy, end = '\n\n')
print('precision = ', precision, end = '\n\n')
print('recall = ', recall, end = '\n\n')

print(np.array(accuracy).mean(), np.array(precision).mean(), np.array(recall).mean())
# Out:
# [[93 13]
#  [12 68]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       106
#            1       0.84      0.85      0.84        80
#
#     accuracy                           0.87       186
#    macro avg       0.86      0.86      0.86       186
# weighted avg       0.87      0.87      0.87       186
#
# [[82 14]
#  [21 69]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82        96
#            1       0.83      0.77      0.80        90
#
#     accuracy                           0.81       186
#    macro avg       0.81      0.81      0.81       186
# weighted avg       0.81      0.81      0.81       186
#
# [[90 14]
#  [22 60]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       104
#            1       0.81      0.73      0.77        82
#
#     accuracy                           0.81       186
#    macro avg       0.81      0.80      0.80       186
# weighted avg       0.81      0.81      0.81       186
#
# [[77 21]
#  [23 65]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        98
#            1       0.76      0.74      0.75        88
#
#     accuracy                           0.76       186
#    macro avg       0.76      0.76      0.76       186
# weighted avg       0.76      0.76      0.76       186
#
# [[86 17]
#  [23 60]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       103
#            1       0.78      0.72      0.75        83
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[85  8]
#  [21 72]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85        93
#            1       0.90      0.77      0.83        93
#
#     accuracy                           0.84       186
#    macro avg       0.85      0.84      0.84       186
# weighted avg       0.85      0.84      0.84       186
#
# [[81 21]
#  [21 63]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       102
#            1       0.75      0.75      0.75        84
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.77      0.77       186
# weighted avg       0.77      0.77      0.77       186
#
# [[78 24]
#  [20 64]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       102
#            1       0.73      0.76      0.74        84
#
#     accuracy                           0.76       186
#    macro avg       0.76      0.76      0.76       186
# weighted avg       0.76      0.76      0.76       186
#
# [[86 13]
#  [26 61]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        99
#            1       0.82      0.70      0.76        87
#
#     accuracy                           0.79       186
#    macro avg       0.80      0.78      0.79       186
# weighted avg       0.79      0.79      0.79       186
#
# [[81  8]
#  [27 70]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82        89
#            1       0.90      0.72      0.80        97
#
#     accuracy                           0.81       186
#    macro avg       0.82      0.82      0.81       186
# weighted avg       0.83      0.81      0.81       186
#
# [[85 23]
#  [19 59]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       108
#            1       0.72      0.76      0.74        78
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.77      0.77       186
# weighted avg       0.78      0.77      0.77       186
#
# [[76 19]
#  [26 65]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        95
#            1       0.77      0.71      0.74        91
#
#     accuracy                           0.76       186
#    macro avg       0.76      0.76      0.76       186
# weighted avg       0.76      0.76      0.76       186
#
# [[90 10]
#  [15 71]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       100
#            1       0.88      0.83      0.85        86
#
#     accuracy                           0.87       186
#    macro avg       0.87      0.86      0.86       186
# weighted avg       0.87      0.87      0.87       186
#
# [[75 14]
#  [31 66]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77        89
#            1       0.82      0.68      0.75        97
#
#     accuracy                           0.76       186
#    macro avg       0.77      0.76      0.76       186
# weighted avg       0.77      0.76      0.76       186
#
# [[72 14]
#  [24 76]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79        86
#            1       0.84      0.76      0.80       100
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[81 25]
#  [17 63]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       106
#            1       0.72      0.79      0.75        80
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.78      0.77       186
# weighted avg       0.78      0.77      0.78       186
#
# [[89 17]
#  [25 55]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       106
#            1       0.76      0.69      0.72        80
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.76      0.77       186
# weighted avg       0.77      0.77      0.77       186
#
# [[84 15]
#  [22 65]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82        99
#            1       0.81      0.75      0.78        87
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[77 19]
#  [22 68]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        96
#            1       0.78      0.76      0.77        90
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[85 16]
#  [31 54]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       101
#            1       0.77      0.64      0.70        85
#
#     accuracy                           0.75       186
#    macro avg       0.75      0.74      0.74       186
# weighted avg       0.75      0.75      0.74       186
#
# accuracy =  [0.8655913978494624, 0.8118279569892473, 0.8064516129032258, 0.7634408602150538, 0.7849462365591398, 0.8440860215053764, 0.7741935483870968, 0.7634408602150538, 0.7903225806451613, 0.8118279569892473, 0.7741935483870968, 0.7580645161290323, 0.8655913978494624, 0.7580645161290323, 0.7956989247311828, 0.7741935483870968, 0.7741935483870968, 0.8010752688172043, 0.7795698924731183, 0.7473118279569892]
#
# precision =  [0.8395061728395061, 0.8313253012048193, 0.8108108108108109, 0.7558139534883721, 0.7792207792207793, 0.9, 0.75, 0.7272727272727273, 0.8243243243243243, 0.8974358974358975, 0.7195121951219512, 0.7738095238095238, 0.8765432098765432, 0.825, 0.8444444444444444, 0.7159090909090909, 0.7638888888888888, 0.8125, 0.7816091954022989, 0.7714285714285715]
#
# recall =  [0.85, 0.7666666666666667, 0.7317073170731707, 0.7386363636363636, 0.7228915662650602, 0.7741935483870968, 0.75, 0.7619047619047619, 0.7011494252873564, 0.7216494845360825, 0.7564102564102564, 0.7142857142857143, 0.8255813953488372, 0.6804123711340206, 0.76, 0.7875, 0.6875, 0.7471264367816092, 0.7555555555555555, 0.6352941176470588]
#
# 0.7922043010752687 0.8000177543239275 0.7434232490459807

# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

df = pd.read_csv('heart_disease_data.csv', header = 0)

x = np.array(df.iloc[:,0:10])
y = np.array(df['num'])

from sklearn import svm
svc = svm.SVC(kernel = 'poly', degree = 3)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

accuracy, precision, recall = list(), list(), list()

for i in range(20):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)
    
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train = scaler.transform(x_train)
    x_test = scaler.transform(x_test)
    
    svc.fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    print(confusion_matrix(y_test, y_pred))

    accuracy.append(accuracy_score(y_test, y_pred))
    precision.append(precision_score(y_test, y_pred, pos_label = 1))
    recall.append(recall_score(y_test, y_pred, pos_label = 1))
    print(classification_report(y_test, y_pred))

print('accuracy = ', accuracy, end = '\n\n')
print('precision = ', precision, end = '\n\n')
print('recall = ', recall, end = '\n\n')

print(np.array(accuracy).mean(), np.array(precision).mean(), np.array(recall).mean())
# Out:
# [[82 14]
#  [18 72]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84        96
#            1       0.84      0.80      0.82        90
#
#     accuracy                           0.83       186
#    macro avg       0.83      0.83      0.83       186
# weighted avg       0.83      0.83      0.83       186
#
# [[79 12]
#  [29 66]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        91
#            1       0.85      0.69      0.76        95
#
#     accuracy                           0.78       186
#    macro avg       0.79      0.78      0.78       186
# weighted avg       0.79      0.78      0.78       186
#
# [[75 17]
#  [24 70]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79        92
#            1       0.80      0.74      0.77        94
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[85 19]
#  [19 63]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       104
#            1       0.77      0.77      0.77        82
#
#     accuracy                           0.80       186
#    macro avg       0.79      0.79      0.79       186
# weighted avg       0.80      0.80      0.80       186
#
# [[79 14]
#  [28 65]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        93
#            1       0.82      0.70      0.76        93
#
#     accuracy                           0.77       186
#    macro avg       0.78      0.77      0.77       186
# weighted avg       0.78      0.77      0.77       186
#
# [[87 20]
#  [23 56]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       107
#            1       0.74      0.71      0.72        79
#
#     accuracy                           0.77       186
#    macro avg       0.76      0.76      0.76       186
# weighted avg       0.77      0.77      0.77       186
#
# [[78 14]
#  [27 67]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        92
#            1       0.83      0.71      0.77        94
#
#     accuracy                           0.78       186
#    macro avg       0.79      0.78      0.78       186
# weighted avg       0.79      0.78      0.78       186
#
# [[82 23]
#  [25 56]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77       105
#            1       0.71      0.69      0.70        81
#
#     accuracy                           0.74       186
#    macro avg       0.74      0.74      0.74       186
# weighted avg       0.74      0.74      0.74       186
#
# [[88 27]
#  [13 58]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.81       115
#            1       0.68      0.82      0.74        71
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.79      0.78       186
# weighted avg       0.80      0.78      0.79       186
#
# [[83 21]
#  [21 61]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       104
#            1       0.74      0.74      0.74        82
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.77      0.77       186
# weighted avg       0.77      0.77      0.77       186
#
# [[81 17]
#  [27 61]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79        98
#            1       0.78      0.69      0.73        88
#
#     accuracy                           0.76       186
#    macro avg       0.77      0.76      0.76       186
# weighted avg       0.77      0.76      0.76       186
#
# [[87 13]
#  [29 57]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81       100
#            1       0.81      0.66      0.73        86
#
#     accuracy                           0.77       186
#    macro avg       0.78      0.77      0.77       186
# weighted avg       0.78      0.77      0.77       186
#
# [[72 12]
#  [33 69]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.86      0.76        84
#            1       0.85      0.68      0.75       102
#
#     accuracy                           0.76       186
#    macro avg       0.77      0.77      0.76       186
# weighted avg       0.78      0.76      0.76       186
#
# [[84 17]
#  [23 62]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       101
#            1       0.78      0.73      0.76        85
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[89 13]
#  [24 60]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       102
#            1       0.82      0.71      0.76        84
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.79      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[84 15]
#  [31 56]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.79        99
#            1       0.79      0.64      0.71        87
#
#     accuracy                           0.75       186
#    macro avg       0.76      0.75      0.75       186
# weighted avg       0.76      0.75      0.75       186
#
# [[87 21]
#  [22 56]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80       108
#            1       0.73      0.72      0.72        78
#
#     accuracy                           0.77       186
#    macro avg       0.76      0.76      0.76       186
# weighted avg       0.77      0.77      0.77       186
#
# [[86 13]
#  [32 55]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        99
#            1       0.81      0.63      0.71        87
#
#     accuracy                           0.76       186
#    macro avg       0.77      0.75      0.75       186
# weighted avg       0.77      0.76      0.75       186
#
# [[85 12]
#  [25 64]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82        97
#            1       0.84      0.72      0.78        89
#
#     accuracy                           0.80       186
#    macro avg       0.81      0.80      0.80       186
# weighted avg       0.81      0.80      0.80       186
#
# [[82 13]
#  [25 66]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81        95
#            1       0.84      0.73      0.78        91
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.79      0.79       186
# weighted avg       0.80      0.80      0.79       186
#
# accuracy =  [0.8279569892473119, 0.7795698924731183, 0.7795698924731183, 0.7956989247311828, 0.7741935483870968, 0.7688172043010753, 0.7795698924731183, 0.7419354838709677, 0.7849462365591398, 0.7741935483870968, 0.7634408602150538, 0.7741935483870968, 0.7580645161290323, 0.7849462365591398, 0.8010752688172043, 0.7526881720430108, 0.7688172043010753, 0.7580645161290323, 0.8010752688172043, 0.7956989247311828]
#
# precision =  [0.8372093023255814, 0.8461538461538461, 0.8045977011494253, 0.7682926829268293, 0.8227848101265823, 0.7368421052631579, 0.8271604938271605, 0.7088607594936709, 0.6823529411764706, 0.7439024390243902, 0.782051282051282, 0.8142857142857143, 0.8518518518518519, 0.7848101265822784, 0.821917808219178, 0.7887323943661971, 0.7272727272727273, 0.8088235294117647, 0.8421052631578947, 0.8354430379746836]
#
# recall =  [0.8, 0.6947368421052632, 0.7446808510638298, 0.7682926829268293, 0.6989247311827957, 0.7088607594936709, 0.7127659574468085, 0.691358024691358, 0.8169014084507042, 0.7439024390243902, 0.6931818181818182, 0.6627906976744186, 0.6764705882352942, 0.7294117647058823, 0.7142857142857143, 0.6436781609195402, 0.717948717948718, 0.632183908045977, 0.7191011235955056, 0.7252747252747253]
#
# 0.7782258064516129 0.7917725408320344 0.7147375457626621

# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

df = pd.read_csv('heart_disease_data.csv', header = 0)

x = np.array(df.iloc[:,0:10])
y = np.array(df['num'])

from sklearn import svm
svc = svm.SVC(kernel = 'rbf')

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

accuracy, precision, recall = list(), list(), list()

for i in range(20):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)
    
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train = scaler.transform(x_train)
    x_test = scaler.transform(x_test)
    
    svc.fit(x_train, y_train)
    y_pred = svc.predict(x_test)
    print(confusion_matrix(y_test, y_pred))

    accuracy.append(accuracy_score(y_test, y_pred))
    precision.append(precision_score(y_test, y_pred, pos_label = 1))
    recall.append(recall_score(y_test, y_pred, pos_label = 1))
    print(classification_report(y_test, y_pred))

print('accuracy = ', accuracy, end = '\n\n')
print('precision = ', precision, end = '\n\n')
print('recall = ', recall, end = '\n\n')

print(np.array(accuracy).mean(), np.array(precision).mean(), np.array(recall).mean())
# Out:
# [[82 25]
#  [20 59]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78       107
#            1       0.70      0.75      0.72        79
#
#     accuracy                           0.76       186
#    macro avg       0.75      0.76      0.75       186
# weighted avg       0.76      0.76      0.76       186
#
# [[81 16]
#  [28 61]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79        97
#            1       0.79      0.69      0.73        89
#
#     accuracy                           0.76       186
#    macro avg       0.77      0.76      0.76       186
# weighted avg       0.77      0.76      0.76       186
#
# [[79 14]
#  [27 66]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.79        93
#            1       0.82      0.71      0.76        93
#
#     accuracy                           0.78       186
#    macro avg       0.79      0.78      0.78       186
# weighted avg       0.79      0.78      0.78       186
#
# [[79 13]
#  [24 70]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81        92
#            1       0.84      0.74      0.79        94
#
#     accuracy                           0.80       186
#    macro avg       0.81      0.80      0.80       186
# weighted avg       0.81      0.80      0.80       186
#
# [[78 19]
#  [23 66]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79        97
#            1       0.78      0.74      0.76        89
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.77      0.77       186
# weighted avg       0.77      0.77      0.77       186
#
# [[79 18]
#  [30 59]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.77        97
#            1       0.77      0.66      0.71        89
#
#     accuracy                           0.74       186
#    macro avg       0.75      0.74      0.74       186
# weighted avg       0.74      0.74      0.74       186
#
# [[86 20]
#  [21 59]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       106
#            1       0.75      0.74      0.74        80
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.77      0.77       186
# weighted avg       0.78      0.78      0.78       186
#
# [[77 16]
#  [22 71]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80        93
#            1       0.82      0.76      0.79        93
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[82 20]
#  [19 65]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81       102
#            1       0.76      0.77      0.77        84
#
#     accuracy                           0.79       186
#    macro avg       0.79      0.79      0.79       186
# weighted avg       0.79      0.79      0.79       186
#
# [[79 13]
#  [24 70]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81        92
#            1       0.84      0.74      0.79        94
#
#     accuracy                           0.80       186
#    macro avg       0.81      0.80      0.80       186
# weighted avg       0.81      0.80      0.80       186
#
# [[80 18]
#  [22 66]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80        98
#            1       0.79      0.75      0.77        88
#
#     accuracy                           0.78       186
#    macro avg       0.79      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[75 20]
#  [23 68]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        95
#            1       0.77      0.75      0.76        91
#
#     accuracy                           0.77       186
#    macro avg       0.77      0.77      0.77       186
# weighted avg       0.77      0.77      0.77       186
#
# [[80 22]
#  [17 67]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       102
#            1       0.75      0.80      0.77        84
#
#     accuracy                           0.79       186
#    macro avg       0.79      0.79      0.79       186
# weighted avg       0.79      0.79      0.79       186
#
# [[87 15]
#  [23 61]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       102
#            1       0.80      0.73      0.76        84
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.79      0.79       186
# weighted avg       0.80      0.80      0.79       186
#
# [[80 14]
#  [23 69]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81        94
#            1       0.83      0.75      0.79        92
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[74 23]
#  [16 73]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79        97
#            1       0.76      0.82      0.79        89
#
#     accuracy                           0.79       186
#    macro avg       0.79      0.79      0.79       186
# weighted avg       0.79      0.79      0.79       186
#
# [[86 13]
#  [24 63]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82        99
#            1       0.83      0.72      0.77        87
#
#     accuracy                           0.80       186
#    macro avg       0.81      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[79 20]
#  [20 67]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        99
#            1       0.77      0.77      0.77        87
#
#     accuracy                           0.78       186
#    macro avg       0.78      0.78      0.78       186
# weighted avg       0.78      0.78      0.78       186
#
# [[77 17]
#  [21 71]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80        94
#            1       0.81      0.77      0.79        92
#
#     accuracy                           0.80       186
#    macro avg       0.80      0.80      0.80       186
# weighted avg       0.80      0.80      0.80       186
#
# [[83 12]
#  [24 67]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82        95
#            1       0.85      0.74      0.79        91
#
#     accuracy                           0.81       186
#    macro avg       0.81      0.80      0.81       186
# weighted avg       0.81      0.81      0.81       186
#
# accuracy =  [0.7580645161290323, 0.7634408602150538, 0.7795698924731183, 0.8010752688172043, 0.7741935483870968, 0.7419354838709677, 0.7795698924731183, 0.7956989247311828, 0.7903225806451613, 0.8010752688172043, 0.7849462365591398, 0.7688172043010753, 0.7903225806451613, 0.7956989247311828, 0.8010752688172043, 0.7903225806451613, 0.8010752688172043, 0.7849462365591398, 0.7956989247311828, 0.8064516129032258]
#
# precision =  [0.7023809523809523, 0.7922077922077922, 0.825, 0.8433734939759037, 0.7764705882352941, 0.7662337662337663, 0.7468354430379747, 0.8160919540229885, 0.7647058823529411, 0.8433734939759037, 0.7857142857142857, 0.7727272727272727, 0.7528089887640449, 0.8026315789473685, 0.8313253012048193, 0.7604166666666666, 0.8289473684210527, 0.7701149425287356, 0.8068181818181818, 0.8481012658227848]
#
# recall =  [0.7468354430379747, 0.6853932584269663, 0.7096774193548387, 0.7446808510638298, 0.7415730337078652, 0.6629213483146067, 0.7375, 0.7634408602150538, 0.7738095238095238, 0.7446808510638298, 0.75, 0.7472527472527473, 0.7976190476190477, 0.7261904761904762, 0.75, 0.8202247191011236, 0.7241379310344828, 0.7701149425287356, 0.7717391304347826, 0.7362637362637363]
#
# 0.7852150537634408 0.7918139609519363 0.7452027659709811
